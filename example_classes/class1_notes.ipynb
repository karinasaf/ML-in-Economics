# %%
import torch
import torchvision

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
x=torch.tensor([[1,2,3], [4,5, 6]])
print(x[1][2]) # prints tensor(6)
print(x[:,:])
# Out:
# tensor(6)
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %% [markdown]
# cross entropy max the probability of having the true answer
